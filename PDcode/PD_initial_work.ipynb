# %%
import numpy as np
import pandas as pd
import math as m
import matplotlib.pyplot as plt
import glob

# %%
data = pd.read_csv('C:/Users/ale/Documents/Tec/PD sensor extracted data/PDdata/2021-03-15/PD_left.csv')
data['t'] = pd.to_datetime(data['t'])
data.head()
# Out:
#                         t      x      y      z
# 0 2021-03-14 23:59:47.627 -1.056  0.256 -0.096
# 1 2021-03-14 23:59:47.667 -1.056  0.256 -0.096
# 2 2021-03-14 23:59:47.697 -1.056  0.256 -0.064
# 3 2021-03-14 23:59:47.737 -1.024  0.256 -0.096
# 4 2021-03-14 23:59:47.767 -1.056  0.256 -0.064

# %%
startdate = pd.to_datetime('2021-03-15 21:00:00.000')
enddate = pd.to_datetime('2021-03-15 23:59:59.000')

plt.figure(figsize=(20, 7.5))
plt.plot(data['t'], data['x'], label='x', color='b') 
plt.plot(data['t'], data['y'], label='y', color='orange') 
plt.plot(data['t'], data['z'], label='z', color='g') 
plt.xlim(startdate, enddate) 
plt.xlabel('time') 
plt.legend() 
plt.show()
